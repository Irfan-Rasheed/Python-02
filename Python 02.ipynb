# %% [markdown]
# Task # 01: Declare a variable called username.

# %%
name="Irfan Rasheed";

# %% [markdown]
# Task # 02:Declare a variable called myName & assign to it a string
# that represents your Full Name.

# %%
name="Irfan Rasheed";
print(name);
# Out:
# Irfan Rasheed

# %% [markdown]
# Task # 03:. Write a code to
#
# a) Declare a variable, titled message.
#
# b) Assign “Hello World” to variable message
#
# c) Print a message.

# %%
message = "Hello World";
print(message);
# Out:
# Hello World

# %% [markdown]
# Task # 04: Write a code to save student’s bio data in a variables and
# show the data in output.

# %%
name = "Irfan Rasheed";
age = 20;
course = "Mobile And Development Application ";
print(name,"\n",age , "Years Old \n",course );
# Out:
# Irfan Rasheed
#  20 Years Old
#  Mobile And Development Application

# %% [markdown]
# Task # 05: Write a code to display the following:
#
# PIZZA
#
# PIZZ
#
# PIZ
#
# PI
#
# P

# %%
print("PIZZA \nPIZZ \nPIZ \nPI \nP")
# Out:
# PIZZA
# PIZZ
# PIZ
# PI
# P

# %% [markdown]
# Task # 06: Declare a variable called email and assign to it a string that
# represents your Email Address(e.g. example@example.com).
# Show the below mentioned message in output.(Hint: use
# string concatenation)

# %%
email="irfan44186@gmail.com";
print("My email address is "+ email);
# Out:
# My email address is irfan44186@gmail.com

# %% [markdown]
# Task # 07: Declare a variable called book & give it the value “A
# smarter way to learn Python”. Display the following
# message in output.

# %%
book = "A Smarter Way to Learn Python";
print("I am trying to learn Python from a book ", book );
# Out:
# I am trying to learn Python from a book  A Smarter Way to Learn Python

# %% [markdown]
# Task # 08: Write a code to display this in output "Yeah ! I can write Python code in Jupytor Notebook".

# %%
text = "I can write Python code in Jupytor Notebook";
print("Yeah!",text);
# Out:
# Yeah! I can write Python code in Jupytor Notebook

# %% [markdown]
# Task # 09: Store following string in a variable and show in alert and
# print through Python.
# “▬▬▬▬▬▬▬▬▬ஜ۩۞۩ஜ▬▬▬▬▬▬▬▬▬”

# %%
a = "▬▬▬▬▬▬▬▬▬ஜ۩۞۩ஜ▬▬▬▬▬▬▬▬▬";
print(a);
# Out:
# ▬▬▬▬▬▬▬▬▬ஜ۩۞۩ஜ▬▬▬▬▬▬▬▬▬
